# %% [markdown]
# ## Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
print("Name:\t\tZain ul Abedin")
print("Father Name:\tMuhammad Askari")
print("Date of Birth:\t17/11/2010")
# Out:
# Name:		Zain ul Abedin
# Father Name:	Muhammad Askari
# Date of Birth:	17/11/2010

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
name = "zain"
father_name = "Muhammad askari"
dob = "17/11/2010"
age = 16
city = "karachi"

# %%
print("My bio:")
print("My name is" ,name)
print("My father name is" ,father_name)
print("My date of birth is" ,dob)
print("My age is", age)
print("My city is", city)
# Out:
# My bio:
# My name is zain
# My father name is Muhammad askari
# My date of birth is 17/11/2010
# My age is 16
# My city is karachi

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
a = 10
b = 5

# Arithmetic Operators
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Modulus:", a % b)

# Comparison Operators
print("a > b:", a > b)
print("a < b:", a < b)
print("a == b:", a == b)
print("a != b:", a != b)

# Logical Operators
print((a > b) and (b < 10))
print((a < b) or (b < 10))
print(not(a < b))

# Assignment Operator
c = 10
c += 5
print("c =", c)
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0
# Modulus: 0
# a > b: True
# a < b: False
# a == b: False
# a != b: True
# True
# True
# True
# c = 15

# %% [markdown]
# 4. Completes the following steps of small task:
# Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
# Mention Variable of Total Marks and assign 300 to it
# Calculate Percentage

# %%
english = 85
islamiat = 90
maths = 95

total_marks = 300
obtained_marks = english + islamiat + maths

percentage = (obtained_marks / total_marks) * 100

print("English Marks:", english)
print("Islamiat Marks:", islamiat)
print("Maths Marks:", maths)
print("Total Marks:", total_marks)
print("Obtained Marks:", obtained_marks)
print("Percentage:", percentage, "%")
# Out:
# English Marks: 85
# Islamiat Marks: 90
# Maths Marks: 95
# Total Marks: 300
# Obtained Marks: 270
# Percentage: 90.0 %
